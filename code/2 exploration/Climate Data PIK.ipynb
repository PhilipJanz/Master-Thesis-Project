# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import xarray as xr

# %%
ds = xr.open_dataset('../../data/raw_source/climate/MWI/CHIRPS-0.05_Malawi_MWI_01_01_01_10/pr_cdd5_CHIRPS-0.05_historical_1981-2022_MWI_01_01_01_10_Malawi.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 42, longitude: 70, latitude: 170)
# Coordinates:
#   * time       (time) datetime64[ns] 1981-01-10 1982-01-10 ... 2022-01-10
#   * longitude  (longitude) float32 32.52 32.57 32.62 32.68 ... 35.88 35.93 35.97
#   * latitude   (latitude) float32 -17.48 -17.42 -17.38 ... -9.125 -9.075 -9.025
# Data variables:
#     pr_cdd5    (time, latitude, longitude) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/...
#     history:      Wed Apr 10 20:12:17 2024: cdo mergetime /home/laudien/clim_...
#     Conventions:  CF-1.6
#     CDO:          Climate Data Operators version 1.9.6 (http://mpimet.mpg.de/...

# %%
ds.attrs
# Out:
# {'CDI': 'Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/cdi)',
# ...

# %%
ds[1, 1 ,1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\envs\geoo\lib\site-packages\xarray\core\dataset.py:1393, in Dataset._construct_dataarray(self, name)
#    1392 try:
# -> 1393     variable = self._variables[name]
#    1394 except KeyError:
#
# KeyError: (1, 1, 1)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ds[1, 1 ,1]
#
# File ~\Anaconda3\envs\geoo\lib\site-packages\xarray\core\dataset.py:1484, in Dataset.__getitem__(self, key)
#    1482     return self.isel(**key)
#    1483 if utils.hashable(key):
# -> 1484     return self._construct_dataarray(key)
#    1485 if utils.iterable_of_hashable(key):
#    1486     return self._copy_listed(key)
#
# ...

# %%
# Out:
# <xarray.DataArray 'longitude' (longitude: 70)>
# array([32.524994, 32.574997, 32.625   , 32.675003, 32.72499 , 32.774994,
#        32.824997, 32.875   , 32.925003, 32.97499 , 33.024994, 33.074997,
#        33.125   , 33.175003, 33.22499 , 33.274994, 33.324997, 33.375   ,
#        33.425003, 33.47499 , 33.524994, 33.574997, 33.625   , 33.675003,
#        33.72499 , 33.774994, 33.824997, 33.875   , 33.925003, 33.97499 ,
#        34.024994, 34.074997, 34.125   , 34.175003, 34.22499 , 34.274994,
#        34.324997, 34.375   , 34.425003, 34.47499 , 34.524994, 34.574997,
#        34.625   , 34.675003, 34.72499 , 34.774994, 34.824997, 34.875   ,
#        34.925003, 34.97499 , 35.024994, 35.074997, 35.125   , 35.175003,
#        35.22499 , 35.274994, 35.324997, 35.375   , 35.425003, 35.47499 ,
#        35.524994, 35.574997, 35.625   , 35.675003, 35.72499 , 35.774994,
#        35.824997, 35.875   , 35.925003, 35.97499 ], dtype=float32)
# Coordinates:
# ...
